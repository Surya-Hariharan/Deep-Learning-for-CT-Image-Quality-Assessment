# %% [markdown]
# # Reference-Level 60/20/20 Split
#
# ## Objective
#
# Visualise and sanity-check the reference-level train/val/test split produced by `ct_iqa.data.splitting.assign_splits` -- confirm no leakage, and that `expert_score` distributions are reasonably balanced across the three partitions.
#
# ## Intended analysis
#
# Call `assign_splits` with the production config's ratios/seed (`configs/quality/ohashi_ldctiqac.yaml`); plot per-split `expert_score` histograms; run `check_group_leakage` and display its report rather than re-deriving leakage detection here.
#
# ## Depends on
#
# `data/manifests/ldctiqa_manifest.csv`, `src/ct_iqa/data/splitting.py`
#
# ## Project status
#
# STATUS: skeleton only -- no cells executed. Core implementation lives in `src/`; this notebook is for EDA / visualization / interpretation, per `docs/project_status.md` (current phase: repository + methodology validation complete; production dataset generation not yet executed).
#
# Do not implement pipeline logic directly in this notebook -- import from `src/ct_iqa` and call into it. This notebook is intentionally waiting for its input to exist (see "Depends on" below) before it is run.
