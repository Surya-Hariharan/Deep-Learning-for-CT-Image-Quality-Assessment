# %% [markdown]
# # Dataset Inventory
#
# ## Objective
#
# Survey every dataset configured in `configs/datasets/*.yaml` (not just LDCT-IQAC) -- presence on disk, image counts, formats, and basic metadata -- as a single before-EDA orientation pass.
#
# ## Intended analysis
#
# Load each dataset's manifest via `ct_iqa.config.loader` / `ct_iqa.data.manifest.read_manifest_csv`; tabulate counts, image dimensions, and modality; cross-reference against `reports/dataset_inventory.md` (already generated by `scripts/dataset/inspect_datasets.py`) rather than re-deriving it by hand.
#
# ## Depends on
#
# `data/manifests/*.csv` (already built, committed)
#
# ## Project status
#
# STATUS: skeleton only -- no cells executed. Core implementation lives in `src/`; this notebook is for EDA / visualization / interpretation, per `docs/project_status.md` (current phase: repository + methodology validation complete; production dataset generation not yet executed).
#
# Do not implement pipeline logic directly in this notebook -- import from `src/ct_iqa` and call into it. This notebook is intentionally waiting for its input to exist (see "Depends on" below) before it is run.
