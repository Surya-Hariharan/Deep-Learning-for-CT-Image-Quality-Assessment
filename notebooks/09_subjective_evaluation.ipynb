# %% [markdown]
# # Subjective / Real-Image Evaluation (Stages 2-3)
#
# ## Objective
#
# Ohashi Stages 2-3: evaluate trained-model predictions against `expert_score` (LDCT-IQAC MOS) -- both the synthetic-condition subjective comparison and the real/unmodified-image evaluation. Per `docs/deviations_from_ohashi.md` DEV-04, both stages draw on the same LDCT-IQAC references in this adaptation; that narrowing should be restated in this notebook's conclusions, not silently dropped.
#
# ## Intended analysis
#
# Load calibrated predictions vs `expert_score` for both stages once available; compute PLCC/SROCC per `configs/quality/resnet50_vif.yaml:evaluation`; explicitly caveat results against DEV-04 rather than presenting Stage 3 as an independent generalisation check.
#
# ## Depends on
#
# A trained model's predictions -- NOT YET AVAILABLE.
#
# ## Project status
#
# STATUS: skeleton only -- no cells executed. Core implementation lives in `src/`; this notebook is for EDA / visualization / interpretation, per `docs/project_status.md` (current phase: repository + methodology validation complete; production dataset generation not yet executed).
#
# Do not implement pipeline logic directly in this notebook -- import from `src/ct_iqa` and call into it. This notebook is intentionally waiting for its input to exist (see "Depends on" below) before it is run.
