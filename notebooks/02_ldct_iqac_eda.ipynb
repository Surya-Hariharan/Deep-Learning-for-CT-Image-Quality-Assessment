# %% [markdown]
# # LDCT-IQAC Exploratory Data Analysis
#
# ## Objective
#
# Characterise the 1,000-image LDCT-IQAC reference set: `expert_score` distribution, image statistics (intensity histograms, contrast), and any visible acquisition artifacts referenced in `docs/dataset_adaptation.md` (DEV-02).
#
# ## Intended analysis
#
# Load `data/manifests/ldctiqa_manifest.csv`; plot the `expert_score` histogram and a stratified sample of reference images across the score range; sanity-check against `docs/dataset_audit.md`.
#
# ## Depends on
#
# `data/manifests/ldctiqa_manifest.csv` (already built, committed)
#
# ## Project status
#
# STATUS: skeleton only -- no cells executed. Core implementation lives in `src/`; this notebook is for EDA / visualization / interpretation, per `docs/project_status.md` (current phase: repository + methodology validation complete; production dataset generation not yet executed).
#
# Do not implement pipeline logic directly in this notebook -- import from `src/ct_iqa` and call into it. This notebook is intentionally waiting for its input to exist (see "Depends on" below) before it is run.
