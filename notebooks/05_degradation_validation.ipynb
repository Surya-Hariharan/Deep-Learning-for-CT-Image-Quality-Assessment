# %% [markdown]
# # Degradation Engine Validation
#
# ## Objective
#
# Visual/statistical inspection of the Gaussian noise/blur/combined degradation engine (`src/ct_iqa/degradation/`) on a handful of real LDCT-IQAC references -- complements, does not replace, `tests/test_degradation.py`.
#
# ## Intended analysis
#
# Apply a spread of conditions from `build_grid()` to a few sample references via `apply_condition`; display before/after image grids; confirm degradation severity increases visually and monotonically with sigma, matching `docs/vif_full_grid_pilot_report.md`'s findings.
#
# ## Depends on
#
# `data/raw/ldctiqa/` (present, read-only), `src/ct_iqa/degradation/`
#
# ## Project status
#
# STATUS: skeleton only -- no cells executed. Core implementation lives in `src/`; this notebook is for EDA / visualization / interpretation, per `docs/project_status.md` (current phase: repository + methodology validation complete; production dataset generation not yet executed).
#
# Do not implement pipeline logic directly in this notebook -- import from `src/ct_iqa` and call into it. This notebook is intentionally waiting for its input to exist (see "Depends on" below) before it is run.
