# %% [markdown]
# # Synthetic Test Set Evaluation (Stage 1)
#
# ## Objective
#
# Ohashi Stage 1: evaluate trained-model predictions against `vif_score` on the synthetic test split (MSE/PLCC/SROCC).
#
# ## Intended analysis
#
# Load test-split predictions once a trained model exists; call `ct_iqa.evaluation.metrics.evaluate_correlation` and `mean_squared_error`; fit the five-parameter logistic calibration (`ct_iqa.evaluation.logistic_calibration`) before computing PLCC.
#
# ## Depends on
#
# A trained model's predictions -- NOT YET AVAILABLE (no model has been trained; see `docs/project_status.md` §12).
#
# ## Project status
#
# STATUS: skeleton only -- no cells executed. Core implementation lives in `src/`; this notebook is for EDA / visualization / interpretation, per `docs/project_status.md` (current phase: repository + methodology validation complete; production dataset generation not yet executed).
#
# Do not implement pipeline logic directly in this notebook -- import from `src/ct_iqa` and call into it. This notebook is intentionally waiting for its input to exist (see "Depends on" below) before it is run.
