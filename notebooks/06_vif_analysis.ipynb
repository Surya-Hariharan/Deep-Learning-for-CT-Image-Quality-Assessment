# %% [markdown]
# # VIF Label Analysis
#
# ## Objective
#
# Analyse VIF label behaviour (distribution, monotonicity, diagnostic flag rates) once production labels exist -- this notebook is the natural home for a full-scale repeat of the analysis already done at pilot scale in `docs/vif_full_grid_pilot_report.md`.
#
# ## Intended analysis
#
# Load the production `quality_iqa_manifest.*` once generated; reproduce the pilot report's distribution/monotonicity/channel-gain breakdowns at full 169,000-record scale; compare against the pilot's figures as a consistency check, not a replacement for them.
#
# ## Depends on
#
# The production manifest (`data/manifests/quality_iqa_manifest.csv`) -- NOT YET GENERATED, see `docs/project_status.md` §11. Until then, this notebook can only be run against the gitignored pilot outputs under `data/interim/vif_full_grid_pilot/`.
#
# ## Project status
#
# STATUS: skeleton only -- no cells executed. Core implementation lives in `src/`; this notebook is for EDA / visualization / interpretation, per `docs/project_status.md` (current phase: repository + methodology validation complete; production dataset generation not yet executed).
#
# Do not implement pipeline logic directly in this notebook -- import from `src/ct_iqa` and call into it. This notebook is intentionally waiting for its input to exist (see "Depends on" below) before it is run.
